# %% [markdown]
# # Replicating Calvano et al. (2020)
# ## Baseline - Impulse functions
# ### Author: Andréa Epivent

# %%
# Set working directory
#path = "/Users/admin/Desktop/PhD/RL_AlgorithmicCollusion"
path = "C:/Users/lambin/Dropbox/Algorithmic_punishment/RL_AlgoCollusion"

# Import packages and custom functions
exec(open(path+"/Functions/import.py").read())

# Import parameters
exec(open(path+"/Functions/parameters.py").read())

# %%
# Import data from training
q_table_1 = np.load(path+'/Output/Baseline/q_table_a1.npy')
q_table_2 = np.load(path+'/Output/Baseline/q_table_a2.npy')
q_info = np.load(path+'/Output/Baseline/q_info.npy')
A = np.load(path+'/Output/Baseline/actions.npy')
S = np.load(path+'/Output/Baseline/states.npy')
n_iterations = np.load(path+'/Output/Baseline/n_iterations.npy')
cycles = np.load(path+'/Output/Baseline/cycles.npy')

# %% [markdown]
# ### Forcing a price cut

# %% [markdown]
# * Full sample

# %%
prices1_down,prices2_down = impulse_function(cycles,n_episodes,"cut",3,"full",q_table_1,q_table_2,q_info,n_iterations,S,A)

# %% [markdown]
# * Convergence to a point (asym & sym)

# %%
prices1_down,prices2_down = impulse_function(cycles,n_episodes,"cut",3,"point",q_table_1,q_table_2,q_info,n_iterations,S,A)

# %% [markdown]
# * Convergence to a point (asym)

# %%
prices1_down,prices2_down = impulse_function(cycles,n_episodes,"cut",3,"point-asym",q_table_1,q_table_2,q_info,n_iterations,S,A)

# %% [markdown]
# * Convergence to a point (sym)

# %%
prices1_down,prices2_down = impulse_function(cycles,n_episodes,"cut",3,"point-sym",q_table_1,q_table_2,q_info,n_iterations,S,A)

# %% [markdown]
# * Convergence to a set

# %%
prices1_down,prices2_down = impulse_function(cycles,n_episodes,"cut",3,"set",q_table_1,q_table_2,q_info,n_iterations,S,A)

# %% [markdown]
# ### Forcing a price raise

# %% [markdown]
# * Full sample

# %%
prices1_up, prices2_up = impulse_function(cycles,n_episodes,"raise",1.5,"full",q_table_1,q_table_2,q_info,n_iterations,S,A)

# %% [markdown]
# * Convergence to a point (asym & sym)

# %%
prices1_up, prices2_up = impulse_function(cycles,n_episodes,"raise",1.5,"point",q_table_1,q_table_2,q_info,n_iterations,S,A)

# %% [markdown]
# * Convergence to a point (asym)

# %%
prices1_up, prices2_up = impulse_function(cycles,n_episodes,"raise",1.5,"point-asym",q_table_1,q_table_2,q_info,n_iterations,S,A)

# %% [markdown]
# * Convergence to a point (sym)

# %%
prices1_up, prices2_up = impulse_function(cycles,n_episodes,"raise",1.5,"point-sym",q_table_1,q_table_2,q_info,n_iterations,S,A)

# %% [markdown]
# * Convergence to a set

# %%
prices1_up, prices2_up = impulse_function(cycles,n_episodes,"raise",1.5,"set",q_table_1,q_table_2,q_info,n_iterations,S,A)
